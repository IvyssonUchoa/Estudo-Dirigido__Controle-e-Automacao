# %% [markdown]
# <div>
#   <center><h2><strong>Controle e Automação</strong></h2></center>
#   <center><h3><strong>ESTUDO DIRIGIDO</strong></h3></center>
# </div><p>

# %% [markdown]
# <div>
# <center><strong>Semestre:</strong> 2025.1<p></center>
# <center><strong>Livro Texto:</strong> Sistemas de Controle Moderno (Dorf & Bishop, 8ª Edição)<p></center>
# <strong>Professor:</strong> Moacy Pereira da Silva<p>
# <strong>Aluno:</strong> Ivysson Fernandes de Queiroz Uchôa<p>

# %% [markdown]
# # Capítulo 7: Método do Lugar das Raízes

# %% [markdown]
# <p>O método do lugar das raízes é uma técnica gráfica utilizada para analisar a estabilidade e o comportamento dinâmico de sistemas de controle. Ele mostra como as raízes da equação característica se deslocam no plano 𝑠
# conforme ocorre a variação de um parâmetro do sistema, geralmente o ganho
# 𝐾. Essa é uma ferramenta fundamental para o projeto e a análise de sistemas de controle, pois auxilia na definição da resposta transitória e na verificação da estabilidade.

# %% [markdown]
# ## 7.1 O Conceito de Lugar das Raízes

# %% [markdown]
# <p>O lugar das raízes é o trajeto que as raízes da equação característica de um sistema seguem no plano ( s ) à medida que o ganho do sistema ((K)) varia. A equação característica é dada por:
#
# $1 + K G(s) = 0$

# %% [markdown]
# <p>Para que um ponto 𝑠 no plano complexo seja uma raiz da equação característica, duas condições devem ser satisfeitas:
#
# <li>Condição de magnitude: ∣KG(s)∣=1</li>
# <li>Condição de ângulo:
# ∠
# 𝐾
# 𝐺
# (
# 𝑠
# )
# =
# 180º
# ±
# 𝑘
# ⋅
# 360º
# k é um número inteiro.</li>

# %% [markdown]
# <p>O método do lugar das raízes é uma técnica gráfica que permite traçar o caminho percorrido pelas raízes da equação característica no plano
# 𝑠 à medida que o parâmetro
# 𝐾 varia de zero até o infinito. Esse método fornece ao engenheiro uma visão clara da sensibilidade das raízes em relação à variação do ganho, sendo uma ferramenta poderosa tanto para análise quanto para projeto de sistemas de controle. Ele também complementa outros métodos clássicos, como o critério de Routh-Hurwitz.
#
# <p>Com base no diagrama do lugar das raízes, é possível identificar de forma rápida se os polos estão em posições adequadas para atender às especificações de desempenho. Caso contrário, o projetista pode ajustar os parâmetros do sistema de forma precisa para alcançar o comportamento desejado.

# %% [markdown]
# ## 7.2 O procedimento do lugar das raízes

# %% [markdown]
# <p>Passos do Procedimento:
#
# * <strong>Identificação dos polos e zeros:</strong>>Determine os polos e zeros do sistema a partir da função de transferência.
#
# * <strong>Construção do Lugar das Raízes</strong>
#
#   * Trace as linhas dos lócus (loci) a partir das posições dos polos e zeros.
#
#   * Calcule os ângulos de entrada e saída dos lócus.
#
#   * Verifique as interseções com o eixo real e analise outras características relevantes, como assíntotas, centros de gravidade e pontos de ruptura.
#
# * <strong>Ajuste do ganho: </strong>Ajuste o valor do ganho
# 𝐾 para observar como as raízes se deslocam no plano
# 𝑠 e identificar a configuração que atende aos critérios de desempenho do sistema.

# %% [markdown]
# <p><strong>Fórmulas Importantes: </strong>
#
# * Requisitos de magnitude e ângulo para a posição das raízes
# $|G(s)| = 1 \quad \text{e} \quad \angle G(s) = 180^\circ + k360^\circ$
#
# <p>O código a seguir implementa o Método do Lugar das Raízes para um sistema de controle em malha única com realimentação

# %%
! pip install control

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

# Definição do numerador e denominador da função de transferência G(s)H(s)
num = [0.5, 1]  # (1/2)s + 1
den = [0.25, 1, 0]  # s(1/4s + 1) = (1/4)s² + s


# Criando a função de transferência GH(s)
GH = ctrl.TransferFunction(num, den)


# Plotando o Lugar das Raízes
plt.figure(figsize=(8,6))
ctrl.rlocus(GH, grid=True)
plt.title("Lugar das Raízes do Sistema de Controle")
plt.xlabel("Parte Real")
plt.ylabel("Parte Imaginária")
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# <p>O gráfico do <strong>Lugar das Raízes</strong> mostra como os pólos do sistema em malha fechada se deslocam no plano complexo (s) à medida que o ganho (<em>K</em>) varia. O comportamento dessas raízes indica a estabilidade do sistema, que pode ser classificada como:</p>
#
# <ul>
#   <li><strong>Estável:</strong> quando todas as raízes estão no semiplano esquerdo (parte real negativa).</li>
#   <li><strong>Marginalmente estável:</strong> quando há raízes localizadas sobre o eixo imaginário.</li>
#   <li><strong>Instável:</strong> quando existem raízes no semiplano direito (parte real positiva).</li>
# </ul>

# %% [markdown]
# ## 7.3 Projeto de Parâmetro pelo Método do Lugar das Raízes

# %% [markdown]
# <p>O <strong>Projeto de Parâmetros pelo Método do Lugar das Raízes</strong> é uma extensão da técnica tradicional do lugar das raízes, que normalmente analisa a variação de um único parâmetro (geralmente o ganho <em>K</em>). Esse método possibilita investigar o efeito de múltiplos parâmetros, como <em>α</em> e <em>β</em>, na posição das raízes da equação característica de um sistema dinâmico.</p>
#
# <p>A ideia principal é adaptar a equação característica para isolar o parâmetro de interesse, transformando-a na forma padrão do lugar das raízes, <em>1 + F(s) = 0</em>. Caso um parâmetro não apareça isoladamente como um coeficiente, a equação pode ser rearranjada para que ele se torne um fator multiplicativo.</p>

# %% [markdown]
# <p>Para lidar com múltiplos parâmetros, a abordagem é realizada de forma sequencial. Por exemplo, considerando dois parâmetros, <em>α</em> e <em>β</em>:</p>
#
# <ol>
#   <li>Inicialmente, um dos parâmetros (por exemplo, <em>β</em>) é fixado em um valor inicial, geralmente zero, e o lugar das raízes é traçado em função do outro parâmetro (por exemplo, <em>α</em>).</li>
#   <li>Com base nos requisitos de desempenho, é selecionado um valor adequado para <em>α</em>, e as raízes resultantes desse primeiro lugar das raízes passam a ser os polos para a etapa seguinte.</li>
#   <li>Em seguida, o lugar das raízes é traçado em função do segundo parâmetro (<em>β</em>), utilizando os polos determinados na etapa anterior. Um valor apropriado para <em>β</em> é então escolhido.</li>
# </ol>
#
# <p>Este método permite projetar sistemas com múltiplos parâmetros ajustáveis, como é o caso do controlador PID, que possui três parâmetros ajustáveis (KP​, KI​, KD​)

# %% [markdown]
# ## 7.4 Sensibilidade e lugar das raízes

# %% [markdown]
# <p>As variações nos parâmetros de um sistema influenciam a posição das raízes, e medir essas variações é fundamental, pois as raízes da equação característica representam os modos dominantes da resposta transitória do sistema.
#
# <p>A sensibilidade de uma raiz em relação a um parâmetro no sistema
# 𝑇
# (
# 𝑠
# ) pode ser definida como:
#
# $S_{K}^{r_i} = \frac{\partial r_i}{\partial \ln K} = \frac{\partial r_i}{\partial K / K}$

# %% [markdown]
# <p>O cálculo da sensibilidade das raízes em um sistema de controle pode ser realizado de forma direta utilizando os métodos do lugar das raízes.
#
# <p>Neste exemplo, será considerado um sistema de segunda ordem representado por uma função de transferência simples, no qual o ganho
# 𝐾 será ajustado para projetar o comportamento desejado.

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

num = [1]  # K
den = [1, 2, 1]  # s^2 + 2s + 1


# Criando a função de transferência
G_H = ctrl.TransferFunction(num, den)


# Plotando o Lugar das Raízes para diferentes valores de K
plt.figure(figsize=(8,6))


# Plotando o Lugar das Raízes com uma grade para facilitar a visualização
ctrl.rlocus(G_H, grid=True)


plt.title("Lugar das Raízes do Sistema com Ganho K Ajustado")
plt.xlabel("Parte Real")
plt.ylabel("Parte Imaginária")
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## 7.5 Controladores de Três Termos (PID)

# %% [markdown]
# <p>O controlador PID é largamente empregado em sistemas de controle automático. Sua atuação baseia-se em três termos fundamentais — proporcional, integral e derivativo — que, combinados, permitem ajustar a saída do sistema de forma eficiente. A função de transferência do controlador PID é expressa por:
#
# $C(s) = K_p + \frac{K_i}{s} + K_d s$
#
# <p>Onde (K_p), (K_i), e (K_d) são os ganhos proporcional, integral e derivativo, respectivamente.
#
# <p>O lugar das raízes pode ser utilizado para ajustar esses parâmetros, garantindo que o sistema atenda aos requisitos de estabilidade e desempenho.

# %% [markdown]
# ## 7.6 Exemplo de Projeto: Sistema de Controle de um Manipulador de Laser

# %% [markdown]
# <p>
#   Considere o sistema de controle de um <strong>manipulador a laser</strong>, o qual deve ser ajustado para executar movimentos com rapidez e alta precisão.
#   O projeto do controlador pode ser realizado por meio do <strong>método do lugar das raízes</strong>, ajustando-se o ganho K e os parâmetros do controlador PID de forma a posicionar as raízes adequadamente no plano s,
#   de modo a satisfazer os critérios de desempenho, como tempo de subida, ultrapassagem e estabilidade.
# </p>
#
# <p>
#   A seguir, será realizada a <strong>simulação</strong> da resposta do sistema a uma entrada em rampa, com o objetivo de analisar a ultrapassagem e o tempo de assentamento.
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

# Definindo os parâmetros do sistema
K = 10  # Ganho
num = [K]  # Numerador da função de transferência
den = [1, 15, 50, 50*K]  # Denominador da função de transferência (com K = 10)


# Criando a função de transferência do sistema
system = ctrl.TransferFunction(num, den)


# Definindo a entrada em rampa: r(t) = A * t (com A = 1 mm/s)
A = 1  # Amplitude da entrada em rampa
time = np.linspace(0, 10, 500)  # Tempo de simulação
rampa = A * time  # Entrada em rampa: r(t) = A * t


# Resposta do sistema a uma entrada em rampa
time, response = ctrl.forced_response(system, time, rampa)


# Plotando a resposta
plt.figure(figsize=(10,6))
plt.plot(time, response, label='Resposta do Sistema')
plt.title('Resposta do Sistema a uma Entrada em Rampa (K = 10)')
plt.xlabel('Tempo [s]')
plt.ylabel('Posição [mm]')
plt.grid(True)
plt.legend()
plt.show()
